# %% [markdown]
# ##Frauded Credit Card Detection
# Main Purpose is to analyze if card transaction was frauded

# %% [markdown]
# At the very begin, we want to read data. Data is from Kaggle (https://www.kaggle.com/mlg-ulb/creditcardfraud). Using pandas lib:

# %%
import pandas as pd
ccdata = pd.read_csv('creditcard.csv')

# %% [markdown]
# ###Some data visualization

# %%
ccdata.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
ccdata.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# To avoid some problems with names in python libraries, I'm changing column 'Class' name to 'Output'

# %%
ccdata.rename(columns={'Class': 'Output'}, inplace=True)

# %%
ccdata.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
ccdata.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %% [raw]
# Wanna see visualization of data, not only raw numbers

# %%
from matplotlib import pyplot as plt
fig1, ax1 = plt.subplots()
ax1.set_title('Amount feature horizontal boxplot')
ax1.set_xlabel('Amount')
ax1.boxplot(ccdata.Amount, notch=True, vert=False)
plt.show()

# %% [markdown]
# Let's look at how output data (column 'Output') is divided

# %%
fig2, ax2 = plt.subplots()
ax2.set_title('Output feature proportions')
ax2.set_xlabel('Output')
out_proportions = ccdata.groupby(['Output']).count()
ax2.bar(x=['Not frauded','Frauded'], height=out_proportions['Amount'])
plt.show()

# %% [markdown]
# As we can see, we have much less not frauded records:

# %%
summary_out_proportions = out_proportions['Amount']/out_proportions['Amount'].sum()
print(summary_out_proportions)
# Out:
# Output
# 0    0.998273
# 1    0.001727
# Name: Amount, dtype: float64

# %% [markdown]
# Now, we will try to see if some of our input variables (Time, V1..V28, Amount) are related with themselves and with 'Output':

# %%
corr = ccdata.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_b1e2beb6_faff_11e9_aafd_b5207aa604a8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b1e2beb6_faff_11e9_aafd_b5207aa604a8row0_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_b1e2beb6_faff_11e9_aafd_b5207aa604a8row0_col2 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_b1e2beb6_faff_11e9_aafd_b5207aa604a8row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b1e2beb6_faff_11e9_aafd_b5207aa604a8row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b1e2beb6_faff_11e9_aafd_b5207aa604a8row0_col5 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_b1e2beb6_faff_11e9_aafd_b5207aa604a8row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# Predictors seems to be independent, so it seems that they may be transformed with PCA.
#
# As we can see, our 'Output' is related more than |0.1| with:
# -> V1
# -> V3
# -> V4
# -> V7
# -> V10
# -> V11
# -> V12
# -> V14
# -> V16
# -> V17
# -> V18

# %%
ccdata_stronger_realted = ccdata[['V1','V3','V4','V7','V10','V11','V12','V14','V16','V17','V18','Output']]
corr2 = ccdata_stronger_realted.corr()
corr2.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e31722ee_fb0c_11e9_9b93_b5207aa604a8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e31722ee_fb0c_11e9_9b93_b5207aa604a8row0_col1 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_e31722ee_fb0c_11e9_9b93_b5207aa604a8row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e31722ee_fb0c_11e9_9b93_b5207aa604a8row0_col3 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_e31722ee_fb0c_11e9_9b93_b5207aa604a8row0_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_e31722ee_fb0c_11e9_9b93_b5207aa604a8row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e31722ee_fb0c_11e9_9b93_b5207aa604a8row0_col6 {
#             background-color:  #7da0f9;
#             color:  #000000;
# ...

# %% [markdown]
# It may be useful info in training the model, but above variables corelations values may be not high enough to state that they are crucial.

# %% [markdown]
# As you may see, we have also 'Time' column in our data, which is log of credit cards payments. We can easily see time series in this:

# %%
fig3, ax3 = plt.subplots()
ax3.set_title('Time distribution')
ax3.set_xlabel('Time')
ax3.set_ylabel('Count')
ax3.hist(ccdata.Time, bins=100)
plt.show()

# %% [markdown]
# We can see diffrence of records count in time. It seems that frequency of transactions is divided into two subsets.
